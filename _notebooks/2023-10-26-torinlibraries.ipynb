# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: Libraries in python
# description: Introduction to libraries in python
# type: plans
# courses: { csp: {week: 10} }
# ---

# %%
movebackwards moveforward moveforward turnleft moveforward moveforward.

# %% [markdown]
# ## Hack 2

# %%
from PIL import Image

image = Image.open("../images/EC2.png")
image.show()

# %% [markdown]
# ## Hack 3

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show(

# %% [markdown]
# ## Hack 4

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [127, 90, 201, 111, 232, 350]
plt.bar(months, sales)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## Hack optional

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt


mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0


model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam()


model.compile(optimizer=optimizer,
                            loss=loss_fn,
                            metrics=['accuracy'])


history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))


plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2946 - accuracy: 0.9146 - val_loss: 0.1394 - val_accuracy: 0.9605
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1402 - accuracy: 0.9584 - val_loss: 0.1019 - val_accuracy: 0.9704
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1065 - accuracy: 0.9676 - val_loss: 0.0863 - val_accuracy: 0.9729
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0883 - accuracy: 0.9727 - val_loss: 0.0724 - val_accuracy: 0.9779
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0747 - accuracy: 0.9770 - val_loss: 0.0722 - val_accuracy: 0.9785

# %% [markdown]
# ## Homework

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate values for x-axis
x = np.linspace(0, 2*np.pi, 100)

# generate values for sine and cosine
y_sin = np.sin(x)
y_cos = np.cos(x)

# plot the functions
plt.plot(x, y_sin, label='Sine')
plt.plot(x, y_cos, label='Cosine')

# add title and legend
plt.title('Sine and Cosine Functions')
plt.legend()

# show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# define the range of angles in degrees
angles = np.arange(0, 361, 10)

# convert angles to radians
angles_rad = np.radians(angles)

# calculate the sine and cosine values for each angle
sine_values = np.sin(angles_rad)
cosine_values = np.cos(angles_rad)

# plot the sine and cosine values
plt.plot(angles, sine_values, label='Sine')
plt.plot(angles, cosine_values, label='Cosine')

# add title and axis labels
plt.title('Sine and Cosine Values for Angles in Degrees')
plt.xlabel('Angle (degrees)')
plt.ylabel('Value')

# add legend
plt.legend()

# show the plot
plt.show()
